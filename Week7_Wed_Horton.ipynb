# %%
#class notebook from 10/6/2021

# %% [markdown]
# ## Plotting in Python

# %% [markdown]
# This second project will introduce you to working with and plotting/respresenting data.
# (Written by Peter Frinchaboy, Mia Bovill, and John Donor)

# %%
# Import the needed fuctions
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Lets plot our data from last class

# %%
# READ IN DATA FILE/
data = np.genfromtxt("munich_temperatures_average_with_bad_data.txt")
Date = data[:,0]
Temp = data[:,1] 

# PLOT TO VERIFY FILE READ I
fig1 = plt.figure(figsize=(20,10))
ax1 = fig1.add_subplot(111)
ax1.scatter(Date,Temp,s=15,c='b',alpha=0.5)

ax1.xaxis.set_tick_params(labelsize=20)
ax1.yaxis.set_tick_params(labelsize=20)

plt.show()

# %%
# READ IN DATA FILE/
data = np.genfromtxt("munich_temperatures_average_with_bad_data.txt")
Date = data[:,0]
Temp = data[:,1] 

# PLOT TO VERIFY FILE READ 
fig1 = plt.figure(figsize=(20,10))
ax1 = fig1.add_subplot(111)
ax1.scatter(Date,Temp,s=15,c='b',alpha=0.5)

ax1.xaxis.set_tick_params(labelsize=20)
ax1.yaxis.set_tick_params(labelsize=20)

# LIMIT TO 2 YEARS
ax1.set_xlim(2001.5,2003.5)

plt.show()

# %% [markdown]
# ## Exercise 1
#
# Now remake the plot using the 'masked' (see Monday's Notebook) data to remove the bad data points

# %%
#code here
data = np.genfromtxt("munich_temperatures_average_with_bad_data.txt")
munich_date = data[:,0]
munich_temp = data[:,1] 

#applying the mask
keep_temperature = (munich_temp < 99) & (munich_temp > -99 ) #want to keep if under 99 and greater than -99
munich_date_new = munich_date[keep_temperature]
munich_temp_new = munich_temp[keep_temperature]

fig2 = plt.figure(figsize=(20,10))
ax2 = fig2.add_subplot(111)
ax2.scatter(munich_date_new,munich_temp_new,s=15,c='b',alpha=0.5)

ax2.xaxis.set_tick_params(labelsize=20)
ax2.yaxis.set_tick_params(labelsize=20)

plt.show()

# %% [markdown]
# ## A second plot
#
# You will first need to download the plain text data file "CG20.dat", that we will read in to have data to plot.

# %%
# This will read in the data into a numpy array
data = np.genfromtxt("CG20.dat", delimiter=",") #delimiter needed because file is comma separated
# This will seperate specific columns of the data into newly created variables
AgeNN = data[:,14]  # Log Age 
DistPc = data[:,17] # Distance
XGC = data[:,18]   # X-coordinate
YGC = data[:,19]   # Y-coordinate
ZGC = data[:,20]   # Z-coordinate
RGC = data[:,21]   # Radius-coordinate

# %% [markdown]
# Next will will gerenerate a first plot of mass vs velocity.
#
# This will introduce the first options you will have.

# %%
# Creating a scatter plot in log log space using an object oriented approach
fig3 = plt.figure()                           # makes a figure
ax3 = fig3.add_subplot(111)                    # make a 1,1,1 (single) figure, 1 by 1 figure
ax3.scatter(XGC,YGC,s=5,c='k',alpha=0.3)      # makes a scatter plot (s = size, c = color, alpha = transparency)
plt.show()

# %%
# Changing the size of the plot -- figsize
fig_size = plt.figure(figsize=(20,15))

ax4 = fig_size.add_subplot(111)
ax4.scatter(XGC,YGC,s=5,c='k',alpha=0.3)    # makes a scatter plot (s = size, c = color, alpha = transparency)
plt.show()

# %% [markdown]
# Well this looks like a nice plot, but if you gave this to someone could they tell what it was a plot of?
#
# We need add labels to inform the reader, also we will limit the plot to only show a portion of the data.

# %%
# Reread the data to get ALL of the columns
data = np.genfromtxt("CG20.dat", delimiter=",", names = True)#names = true, first line is name of column

# this is the same as above
fig_size2 = plt.figure(figsize=(20,15))
ax_fig = fig_size2.add_subplot(111)
ax_fig.scatter(data['X'],data['Y'],s=20,c='k',alpha=0.3)    # makes a scatter plot (s = size, c = color, alpha = transparency)
#calling actual column name

# Now, we will label the axis and set the limits of the axis and increase ticksize of the axis
# Set the start and end of range you want to display on the x and yaxis 
ax_fig.set_xlim(-2000,2000)
ax_fig.set_ylim(-1500,1500)

# add the labels
ax_fig.set_xlabel("$X_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating
ax_fig.set_ylabel("$Y_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating

# increase the size of the numbers on the axes
ax_fig.xaxis.set_tick_params(labelsize=20)
ax_fig.yaxis.set_tick_params(labelsize=20)
plt.show()

# %%
# this is the same as above
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)

# Sizing the points according to a 3rd attribute - rvir
ax.scatter(data['X'],data['Y'],s=200*data['r50'],c='k',alpha=0.3)  

# Now, we will label the axis and set the limits of the axis and increase ticksize of the axis
# Set the start and end of range you want to display on the x and yaxis 
ax.set_xlim(-2000,2000)
ax.set_ylim(-1500,1500)

# add the labels
ax.set_xlabel("$X_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating
ax.set_ylabel("$Y_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating

# increase the size of the numbers on the axes
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
plt.show()

# %%
# this is the same as above
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)

# Coloring the points by a 4th attribute and adding a color bar, coloring by log age
image = ax.scatter(data['X'],data['Y'],s=200*data['r50'],c=data['AgeNN'],edgecolor='k',cmap="viridis",alpha=0.5)
bar = fig.colorbar(image,orientation="vertical",pad=0.01)
bar.set_label('$log_{10} (Age)$',size=15)


# Now, we will label the axis and set the limits of the axis and increase ticksize of the axis
# Set the start and end of range you want to display on the x and yaxis 
ax.set_xlim(-2000,2000)
ax.set_ylim(-1500,1500)

# add the labels
ax.set_xlabel("$X_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating
ax.set_ylabel("$Y_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating

# increase the size of the numbers on the axes
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)


plt.show()

# %%
# this is the same as above
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)

# Coloring the points by a 4th attribute and adding a color bar
image = ax.scatter(data['X'],data['Y'],s=200*data['r50'],c=data['AgeNN'],edgecolor='k',cmap="viridis",alpha=0.5)
bar = fig.colorbar(image,orientation="vertical",pad=0.01)
bar.set_label('$log_{10} (Age)$',size=15)
#this command labels the colorbar


# Now, we will label the axis and set the limits of the axis and increase ticksize of the axis
# Set the start and end of range you want to display on the x and yaxis 
ax.set_xlim(-2000,2000)
ax.set_ylim(-1500,1500)

# add the labels
ax.set_xlabel("$X_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating
ax.set_ylabel("$Y_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating

# NOW WE CAN ADD TEXT!!
ax.text(-1300, 1200, "Text is Awesome!",size=20)
ax.text(10, -1300, "And you can put it anywhere!",size=30)

# increase the size of the numbers on the axes
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)

plt.show()

# %%
# this is the same as above
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)

# Coloring the points by a 4th attribute and adding a color bar
image = ax.scatter(data['X'],data['Y'],s=200*data['r50'],c=data['AgeNN'],edgecolor='k',cmap="viridis",alpha=0.5)
#cmap = viridis is good for colorblind
bar = fig.colorbar(image,orientation="vertical",pad=0.01)
bar.set_label('$log_{10} (Age)$',size=15)

ax.text(100, -1400, "You can also insert subplots!",size=30)

# Inserting a subplot
ax_sub = fig.add_axes([0.5,0.2,0.2,0.2])
ax_sub.hist(data['nbstars07'],bins=np.logspace(0,3,20),log='True')
ax_sub.set_xscale('log')


ax.set_xlim(-2000,2000)
ax.set_ylim(-1500,1500)

ax.set_xlabel("$X_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating
ax.set_ylabel("$Y_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating






# increase the size of the numbers on the axes
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)

plt.show()

# %%
# Adding multiple plots
fig = plt.figure(figsize=(20,15))

ax1 = fig.add_subplot(221)
ax1.scatter(data['X'],data['Y'], c ='c')

ax2 = fig.add_subplot(222)
ax2.scatter(data['Y'],data['Z'], c = 'r')

ax3 = fig.add_subplot(223)
ax3.scatter(data['X'],data['Z'], c = 'k')

ax4 = fig.add_subplot(224)
ax4.scatter(data['Rgc'],data['Z'], c = 'g')

plt.show()

# %%
fig = plt.figure(figsize=(20,15))

# Condensing the plots
fig.subplots_adjust(hspace=0.0, wspace=0.0)


ax1 = fig.add_subplot(221)
ax1.scatter(data['Rgc'],data['Z'])

ax2 = fig.add_subplot(222)
ax2.scatter(data['Rgc'],data['Z'])

ax3 = fig.add_subplot(223)
ax3.scatter(data['Rgc'],data['Z'])

ax4 = fig.add_subplot(224)
ax4.scatter(data['Rgc'],data['Z'])

# Removing unneeded tick axis
ax1.set_xticks([])
ax2.set_yticks([])
ax2.set_xticks([])
ax4.set_yticks([])

# AND CAN SAVE YOUR FIGURES  (jpeg, pdf)! 
#plt.show()
#plt.savefig("CG20_tmp.jpeg")
# Out:
# []

# %% [markdown]
# # Exercise - Make a 4-panel Plot.
# 1) GLON vs. GLAT
#
# 2) pmRA* vs pmDE
#
# 3) Rgc vs. Z
#
# 4) AgeNN vs. DistPc
#
# Give the sizes of the points by 'r50' and color the points by AgeNN. Make sure to label your axis and include a colorbar.
# #Extra awesome for adding an inserted histgram of 'nbstars07' into one of its plots.

# %%
# Adding multiple plots
fig_four_plots = plt.figure(figsize=(20,15))

ax1_four = fig_four_plots.add_subplot(221)
image_1 = ax1_four.scatter(data['GLON'],data['GLAT'], s = 200*data['r50'], c = data['AgeNN'],cmap="viridis",alpha=0.5)
ax1_four.set_xlabel("$GLON$ $(degrees)$",size=17)  
ax1_four.set_ylabel("$GLAT$ $(degrees)$",size=17)   
ax1_four.xaxis.set_tick_params(labelsize=17)
ax1_four.yaxis.set_tick_params(labelsize=17)
bar_1 = fig_four_plots.colorbar(image_1,orientation="vertical",pad=0.01)
bar_1.set_label('$log_{10}$ $(Age)$',size=17)
bar_1.ax.tick_params(labelsize=17)

ax2_four = fig_four_plots.add_subplot(222)
image_2 = ax2_four.scatter(data['pmRA'],data['pmDE'], s = 200*data['r50'], c = data['AgeNN'], cmap="viridis",alpha=0.5)
ax2_four.set_xlabel("$pmRA$",size=17)  
ax2_four.set_ylabel("$pmDE$",size=17)   
ax2_four.xaxis.set_tick_params(labelsize=17)
ax2_four.yaxis.set_tick_params(labelsize=17)
bar_2 = fig_four_plots.colorbar(image_2,orientation="vertical",pad=0.01)
bar_2.set_label('$log_{10}$ $(Age)$',size=17)
bar_2.ax.tick_params(labelsize=17)
ax2_four_sub = fig_four_plots.add_axes([0.74,0.76,0.1,0.1])
ax2_four_sub.hist(data['nbstars07'],bins=np.logspace(0,3,20),log='True')
ax2_four_sub.set_xscale('log')
ax2_four_sub.set_title("nbstars07", fontsize=15)



ax3_four = fig_four_plots.add_subplot(223)
image_3 = ax3_four.scatter(data['Rgc'],data['Z'], s = 200*data['r50'], c = data['AgeNN'],cmap="viridis",alpha=0.5)
ax3_four.set_xlabel("$Rgc$",size=17)  
ax3_four.set_ylabel("$Z$ $(pc)$",size=17)   
ax3_four.xaxis.set_tick_params(labelsize=17)
ax3_four.yaxis.set_tick_params(labelsize=17)
bar_3 = fig_four_plots.colorbar(image_3,orientation="vertical",pad=0.01)
bar_3.set_label('$log_{10}$ $(Age)$',size=17)
bar_3.ax.tick_params(labelsize=17)

ax4_four = fig_four_plots.add_subplot(224)
image_4 = ax4_four.scatter(data['AgeNN'],data['DistPc'], s = 200*data['r50'], c = data['AgeNN'],cmap="viridis",alpha=0.5)
ax4_four.set_xlabel("$Log_{10}$ $Age$",size=17)  
ax4_four.set_ylabel("$Distance$ $(pc)$",size=17)   
ax4_four.xaxis.set_tick_params(labelsize=17)
ax4_four.yaxis.set_tick_params(labelsize=17)
bar_4 = fig_four_plots.colorbar(image_4,orientation="vertical",pad=0.01)
bar_4.set_label('$log_{10}$ $(Age)$',size=17)
bar_4.ax.tick_params(labelsize=17)

plt.show()
